# %%
# %matplotlib inline
import timeit

from main import QuantumFeatureSelection
hw4 = QuantumFeatureSelection()

# Running the Tabu Sampler and Simmulated Annealing
# %time hw4.tabu_sampler()
# %time hw4.simulated_annealing()
# Out:
# Printing plot for all features
# 8 no of features selected: ['categoryname', 'thrcnt_week', 'thrcnt_month', 'ip', 'thrcnt_day', 'ipcategory_name', 'flowscore', 'isiptrusted']
# plotting BQM model graph
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="4c0c8d6f-7b19-4cba-a757-fc0360201fd0" data-root-id="1027"></div>
# ----- Pre-processing done -----
#
# Tabu Sampler....
# Submitting for k=1
# Submitting for k=2
# Submitting for k=3
# Submitting for k=4
# Submitting for k=5
# Submitting for k=6
# Submitting for k=7
# Submitting for k=8
# Wall time: 4.86 s
#
# Simulated Annealing....
# Submitting for k=1
# Submitting for k=2
# Submitting for k=3
# Submitting for k=4
# Submitting for k=5
# Submitting for k=6
# Submitting for k=7
# Submitting for k=8
# Wall time: 147 ms

# %%
# Running Feature Selection on the D-Wave Quantum Annealer
# %time hw4.dwave_physical_DW_2000Q_5()
# Out:
# D-wave quantum annealer....
# Maximum chain length for minor embedding is 3.
# Submitting for k=1
# Submitting for k=2
# Submitting for k=3
# Submitting for k=4
# Submitting for k=5
# Submitting for k=6
# Submitting for k=7
# Submitting for k=8
# Wall time: 2min 19s

# %%
print("\n\n *** Setting up 30 features to select from for D-Wave Quantum Annealer to solve Feature Selection *** ")
qfs_30 = QuantumFeatureSelection(max_features=30)
qfs_30.dwave_physical_DW_2000Q_5()
# Out:
#  *** Setting up 30 features to select from for D-Wave Quantum Annealer to solve Feature Selection ***
# Printing plot for all features
# 30 no of features selected: ['categoryname', 'thrcnt_week', 'ip', 'eventname_cd', 'thrcnt_month', 'thrcnt_day', 'p6', 'p8w', 'ipcategory_name', 'flowscore', 'p5d', 'dstportcategory_dominate', 'srcipcategory_cd', 'p8d', 'srcipcategory_dominate', 'parent_category', 'p5w', 'overallseverity', 'timestamp_dist', 'direction_cd', 'srcportcategory_dominate', 'p8m', 'start_hour', 'p5m', 'ipcategory_scope', 'alerttype_cd', 'dstipcategory_cd', 'untrustscore', 'severity_cd', 'isiptrusted']
# plotting BQM model graph
# ...
#   <div class="bk-root" id="e63b9f83-86c4-4cea-aa9f-28e7e5a342a3" data-root-id="1227"></div>
# ----- Pre-processing done -----
#
# D-wave quantum annealer....
# Maximum chain length for minor embedding is 9.
# Submitting for k=1
# Submitting for k=2
# Submitting for k=3
# Submitting for k=4
# Submitting for k=5
# Submitting for k=6
# ...

# %%
from main import QuantumFeatureSelection
qfs = QuantumFeatureSelection(max_features=30)
# %time qfs.tabu_sampler()
# %time qfs.simulated_annealing()
# qfs.dwave_physical_DW_2000Q_5()
# Out:
# Printing plot for all features
# 30 no of features selected: ['p5m', 'p8m', 'overallseverity', 'ipcategory_name', 'timestamp_dist', 'ipcategory_scope', 'direction_cd', 'ip', 'p5d', 'srcipcategory_cd', 'thrcnt_day', 'thrcnt_month', 'dstportcategory_dominate', 'thrcnt_week', 'severity_cd', 'p8w', 'p6', 'parent_category', 'flowscore', 'srcportcategory_dominate', 'isiptrusted', 'p5w', 'srcipcategory_dominate', 'untrustscore', 'alerttype_cd', 'categoryname', 'eventname_cd', 'p8d', 'dstipcategory_cd', 'start_hour']
# plotting BQM model graph
# ...
#   <div class="bk-root" id="6e9f6911-2c12-4c6d-8ceb-a82cdfc1242b" data-root-id="2847"></div>
# ----- Pre-processing done -----
#
# Simulated Annealing....
# Submitting for k=1
# Submitting for k=2
# Submitting for k=3
# Submitting for k=4
# Submitting for k=5
# Submitting for k=6
# Submitting for k=7
# Submitting for k=8
# Submitting for k=9
# Submitting for k=10
# Submitting for k=11
# Submitting for k=12
# Submitting for k=13
# Submitting for k=14
# ...

# %%
from main import QuantumFeatureSelection
qfs_60 = QuantumFeatureSelection(max_features=60)
# %time qfs_60.dwave_physical_DW_2000Q_5()
# Out:
# Printing plot for all features
# 60 no of features selected: ['enforcementscore', 'isiptrusted', 'ip', 'ipcategory_name', 'n7', 'p8w', 'start_hour', 'eventname_cd', 'correlatedcount', 'thrcnt_month', 'p9', 'p5w', 'srcipcategory_cd', 'dstipcategory_cd', 'devicevendor_cd', 'dstportcategory_dominate', 'n4', 'n10', 'overallseverity', 'alerttype_cd', 'start_second', 'thrcnt_day', 'score', 'srcportcategory_dominate', 'protocol_cd', 'p5m', 'p5d', 'devicetype_cd', 'dstipcategory_dominate', 'p8m', 'p8d', 'direction_cd', 'parent_category', 'timestamp_dist', 'untrustscore', 'trustscore', 'n6', 'severity_cd', 'n1', 'n9', 'start_minute', 'weekday', 'n3', 'grandparent_category', 'srcport_cd', 'n5', 'categoryname', 'srcipcategory_dominate', 'reportingdevice_cd', 'n2', 'p6', 'dstip_cd', 'dstport_cd', 'domain_cd', 'flowscore', 'thrcnt_week', 'n8', 'ipcategory_scope', 'username_cd', 'srcip_cd']
# plotting BQM model graph
#     <div class="bk-root">
# ...
